# %%
import os
import pandas as pd

# Define the directory containing the CSV files
directory = './query_youtube_data/'

# List to hold dataframes
dfs = []

# Loop through the directory to find CSV files
for filename in os.listdir(directory):
    if filename.endswith('.csv'):
        file_path = os.path.join(directory, filename)
        print(f"Processing file: {file_path}")
        # Read each CSV file and append to the list
        dfs.append(pd.read_csv(file_path))

# Concatenate all dataframes in the list into a single dataframe
combined_df = pd.concat(dfs, ignore_index=True)

# Define the output file path
output_file = 'youtube_data.csv'

# Save the combined dataframe to a new CSV file
combined_df.to_csv(output_file, index=False)

print(f"Combined CSV file created: {output_file}")
# Out:
# Processing file: ./query_youtube_data/[3] - how to become a pilot.csv
# Processing file: ./query_youtube_data/[1] - luxury car reviews.csv
# Processing file: ./query_youtube_data/[2] - cooking hacks.csv
# Processing file: ./query_youtube_data/[0] - popular YouTube challenges.csv
# Combined CSV file created: youtube_data.csv

# %%
# Load the dataset
df = pd.read_csv('youtube_data.csv')

df.head()
# Out:
#       video_id                                              title  \
# 0  C1-vvXqlehc  Want to become a pilot in Nepal after 10 th & ...
# 1  oT4qL8A9_Yk  இலங்கையிலிருந்து எப்படி விமானி ஆகலாம்|how to b...
# 2  DPdF9sA9nog          Dreams are coming true - Becoming a pilot
# 3  fb0Rq-DW_Yg  How to Become a Pilot in 2024 | Pilot Salaries...
# 4  02-gfh6CNwM  Boeing offers program to help employees become...
#
#                                        thumbnail_url  views  likes  comments  \
# 0  https://i.ytimg.com/vi/C1-vvXqlehc/maxresdefau...   2365    105        60
# 1  https://i.ytimg.com/vi/oT4qL8A9_Yk/maxresdefau...    690     53        11
# 2  https://i.ytimg.com/vi/DPdF9sA9nog/maxresdefau...    317     26         2
# 3  https://i.ytimg.com/vi/fb0Rq-DW_Yg/maxresdefau...   4958    223        39
# 4  https://i.ytimg.com/vi/02-gfh6CNwM/maxresdefau...   1056     19         3
#
#    subscriber_count           date_posted  duration  \
# 0               382  2021-07-07T14:47:51Z     309.0
# 1              6870  2024-05-10T10:01:40Z     849.0
# 2              4880  2024-09-03T09:29:01Z    5888.0
# 3             25000  2024-08-12T17:30:11Z    2673.0
# 4            241000  2022-02-16T05:11:52Z     202.0
#
#                                                 tags              category
# 0         ['#pilot in Nepal', '#fulll details 2021']             Education
# 1                                                 []       Travel & Events
# 2                                                 []  Science & Technology
# 3  ['pilot interview', 'pilot podcast', 'pilot in...         Entertainment
# 4  ['stl', 'st. louis', 'news', 'local news', 'kt...       News & Politics

# %%
df.describe()
# Out:
#               views         likes      comments  subscriber_count     duration
# count  1.190000e+02  1.190000e+02    119.000000      1.190000e+02   119.000000
# mean   1.067648e+06  3.516346e+04   1366.235294      3.440673e+06   634.445378
# std    8.601542e+06  2.947287e+05   8921.595620      2.880847e+07   772.921321
# min    1.600000e+01  0.000000e+00      0.000000      5.000000e+00    60.000000
# 25%    2.045000e+02  7.500000e+00      1.000000      9.055000e+02   242.500000
# 50%    1.011000e+03  3.000000e+01      6.000000      3.960000e+03   434.000000
# 75%    9.626500e+03  3.265000e+02     44.000000      4.650000e+04   744.500000
# max    9.288029e+07  3.145894e+06  87269.000000      3.130000e+08  5888.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.histplot(df['views'], bins=30, kde=True)
plt.title('Distribution of Views')
plt.xlabel('Views')
plt.ylabel('Frequency')
plt.show()
